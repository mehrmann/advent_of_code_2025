// %%
val test_input = """
"""

// %%
import java.nio.file.Files
import java.nio.file.Paths

val use_input = false
val input = if (use_input) {
    Files.readString(Paths.get("input.txt"))
} else {
    test_input
}.trim().split('\n')

input
// Out:
// []
